# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

datos = pd.read_csv('USArrests.csv')
columnas = ['Murder', 'Assault', 'UrbanPop','Rape']
datos2 = datos[columnas]
datos2 = (datos2 - datos2.mean())/datos.std()

# %%
cov_matrix = np.cov(datos2.T)

values, vectors = np.linalg.eig(cov_matrix)

vector_A = vectors[:,0]
vector_B = vectors[:,1]

plt.figure(figsize=(12,12))
datos = np.array(datos)

for i in range(len(datos)):
    model = datos[:,0][i]
    v = np.array(datos2.iloc[i])
    x = np.dot(vector_A, v) 
    y = np.dot(vector_B, v) 
    plt.text(x,-y, model, fontsize=10, color='blue')
    plt.scatter(x, -y, s=0.001)

for j in range(len(columnas)):
    plt.arrow(0.0, 0.0, 2.5*vector_A[j]np.array([1,-1,1,-1])@, -2.5*vector_B[j], color='red', head_width=0.1)
    plt.text(2.75*vector_A[j], 2.75*vector_B[j], columnas[j], color='red')
plt.ylim(-3,3)
plt.xlabel('Primera Componente Principal')
plt.ylabel('Segunda Componente Principal')
plt.savefig('componentes_principales.png', bbox_inches='tight')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-40-96faca03a29d> in <module>
#      18
#      19 for j in range(len(columnas)):
# ---> 20     plt.arrow(0.0, 0.0, 2.5*np.array([1,-1,1,-1])@vector_A[j], -2.5*vector_B[j], color='red', head_width=0.1)
#      21     plt.text(2.75*vector_A[j], 2.75*vector_B[j], columnas[j], color='red')
#      22 plt.ylim(-3,3)
#
# ValueError: matmul: Input operand 1 does not have enough dimensions (has 0, gufunc core with signature (n?,k),(k,m?)->(n?,m?) requires 1)

# %%
datos = np.array(datos)

# %%
datos[:,0][0]
# Out:
# 'Alabama'

# %%
vector_A
# Out:
# array([0.53589947, 0.58318363, 0.27819087, 0.54343209])
